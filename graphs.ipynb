# %%
from matplotlib import pyplot as plt

# %%
k = [12, 24, 36]
model = ["BERT", "GPT-2", "GloVe", "fastText"]
dataset = ["IMDB", "Yelp", "AG News"]
y1 = [
     [0.092, 0.034, 0.026],
     [0.104, 0.056, 0.032],
     [0.058, 0.026, 0.014],
     [0.11, 0.04, 0.022]
]
y2 = [
    [0.104, 0.024, 0.024],
    [0.118, 0.038, 0.03],
    [0.056, 0.032, 0.014],
    [0.086, 0.032, 0.02]
]
k3 = [12, 24, 36, 48]
y3 = [
    [0.402, 0.252, 0.198, 0.16],
    [0.236, 0.184, 0.124, 0.106],
    [0.368, 0.25, 0.186, 0.148],
    [0.326, 0.198, 0.142, 0.11]
]

# %%
plt.rc('axes', titlesize=20)
plt.rc('legend', fontsize=16)
plt.rc('axes', labelsize=16)
plt.rc('font', size=16)  
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(15,7))
for y in y1:
  ax1.plot(k, y, "-o")
for y in y2:
  ax2.plot(k, y, "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Number of Generated Words per Attack (K)")
plt.title("Polarity Classification Attack Accuracy\n\n")

plt.ylabel("Attacked Accuracy\n")
ax1.set_title("IMDB")
ax2.set_title("Yelp")
# Out:
# Text(0.5, 1.0, 'Yelp')

# %%
query = [
  [122.3278,186.008,236.8229,280.3905],
  [123.2304,180.2623,235.6324,279.3311],
  [135.557,207.0667,265.1007,327.0704],
  [147.8101, 220.4788, 294.9277, 343.7955]
]
rate = [
  [0.175, 0.1681, 0.1618, 0.1502],
  [0.1488, 0.1406, 0.1344, 0.1279],
  [0.1749, 0.1656, 0.1604, 0.1565],
  [0.1724, 0.1656, 0.1579, 0.1523]
]
for y in y3:
  plt.plot(k3, y, "-o")
fig = plt.gcf()
fig.set_size_inches(7, 7)
plt.xlabel("Number of Generated Words per Attack (K)")
plt.ylabel("Attacked Accuracy")
plt.title("News Category Classification Attack Accuracy\n\nAG News")
plt.legend(model)
plt.show()

for i in range(len(model)):
  plt.plot(k3, query[i], "-o")
fig = plt.gcf()
fig.set_size_inches(7, 7)
plt.ylabel("Average Number of Queries")
plt.xlabel("Number of Generated Words per Attack (K)")
plt.title("News Category Classification Queries\n\nAG News")
plt.legend(model)
plt.show()

for i in range(len(model)):
  plt.plot(k3, rate[i], "-o")
fig = plt.gcf()
fig.set_size_inches(7, 7)
plt.ylabel("Change Rate")
plt.xlabel("Number of Generated Words per Attack (K)")
plt.title("News Category Classification Change Rate\n\nAG News")
plt.legend(model)
plt.show()

# %%
q1 = [
  [424.163,484.9524,545.4209],
  [416.3281,527.178,598.8368],
  [448.4331,539.7084,600.712],
  [412.7146, 524.1146, 615.5665]
]
c1 = [
  [0.0532, 0.0419, 0.0377],
  [0.04, 0.035, 0.0321],
  [0.0481, 0.038, 0.0339],
  [0.0377, 0.0352, 0.0323]
]
q2 = [
  [283.471, 344.8586, 392.2561],
  [315.7732, 391.4345, 464.0845], 
  [295.125, 360.2913, 427.0629],
  [303.1729, 371.8616, 418.902]
]
c2 = [
  [0.0672, 0.0571, 0.0506], [0.0608, 0.0531, 0.0489], [0.0653, 0.0534, 0.0481], [0.0588, 0.0485, 0.0425]
]
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(15,7))
for i in range(len(model)):
  ax1.plot(k, c1[i], "-o")
for i in range(len(model)):
  ax2.plot(k, c2[i], "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Number of Generated Words per Attack (K)")
plt.title("Polarity Classification Change Rate\n\n")

plt.ylabel("Change Rate\n")
ax1.set_title("IMDB")
ax2.set_title("Yelp")

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(15,7))
for i in range(len(model)):
  ax1.plot(k, q1[i], "-o")
for i in range(len(model)):
  ax2.plot(k, q2[i], "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Number of Generated Words per Attack (K)")
plt.title("Polarity Classification Queries\n\n")

plt.ylabel("Average Number of Queries\n")
ax1.set_title("IMDB")
ax2.set_title("Yelp")
# Out:
# Text(0.5, 1.0, 'Yelp')

# %%
# attack accuracy: mir, rand, lir
xval = ["lir", "rand", "mir"]
# imdb, yelp, ag news
bert = [
    [0.226,0.1,0.092],
    [0.254,0.126,0.104],
    [0.408,0.392,0.402]
]
gpt = [
    [0.254,0.134,0.104],
    [0.31,0.126,0.118],
    [0.34,0.264,0.236]
]
glove = [
    [0.162,0.082,0.058],
    [0.14,0.168,0.056],
    [0.388,0.362,0.368]
]
fast = [
    [0.236,0.14,0.11],
    [0.228,0.132,0.086],
    [0.308,0.314,0.326]
]
total = [bert, gpt, glove, fast]
f, axs = plt.subplots(3, 1, sharex=True, figsize=(7,22))
for m in total:
    for i in range(len(dataset)):
      axs[i].plot(xval, m[i], "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Word Importance Ordering")

plt.ylabel("Attack Accuracy\n")
for i, t in enumerate(dataset):
    axs[i].set_title(t)

# %%
# attack accuracy: mir, rand, lir
xval = ["lir", "rand", "mir"]
# imdb, yelp, ag news
bert = [
    [0.0752,0.0898,0.0532],
    [0.1201,0.1052,0.0672],
    [0.1797,0.1959,0.175]
]
gpt = [
    [0.0542,0.065,0.04],
    [0.0981,0.1052,0.0608],
    [0.161,0.1689,0.1488]
]
glove = [
    [0.0709,0.0785,0.0481],
    [0.105,0.0876,0.0653],
    [0.1771,0.1849,0.1749]
]
fast = [
    [0.0619,0.0673,0.0377],
    [0.0919,0.0861,0.0588],
    [0.1773,0.1877,0.1724]
]
total = [bert, gpt, glove, fast]
f, axs = plt.subplots(3, 1, sharex=True, figsize=(7,22))
for m in total:
    for i in range(len(dataset)):
      axs[i].plot(xval, m[i], "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Word Importance Ordering")

plt.ylabel("Change Rate\n")
for i, t in enumerate(dataset):
    axs[i].set_title(t)

# %%
# attack accuracy: mir, rand, lir
xval = ["lir", "rand", "mir"]
# imdb, yelp, ag news
bert = [
    [734.5426,576.9156,424.163],
    [505.2922,384.7208,283.471],
    [125.1588,132.898,122.3278]
]
gpt = [
    [835.2735,613.9099,416.3281],
    [523.5507,384.7208,315.7732],
    [138.7485,139.2554,123.2304]
]
glove = [
    [874.8019,626.3595,448.4331],
    [573.8698,420.976,295.125],
    [146.5621,141.5141,135.557]
]
fast = [
    [710.411,585.0186,412.7146],
    [482.285,413.4977,303.1729],
    [159.8526,157.5335,147.8101]
]
total = [bert, gpt, glove, fast]
f, axs = plt.subplots(3, 1, sharex=True, figsize=(7,22))
for m in total:
    for i in range(len(dataset)):
      axs[i].plot(xval, m[i], "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Word Importance Ordering")

plt.ylabel("Average Number of Queries\n")
for i, t in enumerate(dataset):
    axs[i].set_title(t)
