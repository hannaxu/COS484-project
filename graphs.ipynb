# %%
from matplotlib import pyplot as plt

# %%
k = [12, 24, 36]
model = ["BERT", "GPT-2", "GloVe", "fastText"]
dataset = ["IMDB, Yelp, AG News"]
y1 = [
     [0.092, 0.034, 0.026],
     [0.104, 0.056, 0.032],
     [0.058, 0.026, 0.014],
     [0.11, 0.04, 0.022]
]
y2 = [
    [0.104, 0.024, 0.024],
    [0.118, 0.038, 0.03],
    [0.056, 0.032, 0.014],
    [0.086, 0.032, 0.02]
]
k3 = [12, 24, 36, 48]
y3 = [
    [0.402, 0.252, 0.198, 0.16],
    [0.236, 0.184, 0.124, 0.106],
    [0.368, 0.25, 0.186, 0.148],
    [0.326, 0.198, 0.142, 0.11]
]

# %%
plt.rc('axes', titlesize=20)
plt.rc('legend', fontsize=16)
plt.rc('axes', labelsize=16)
plt.rc('font', size=16)  
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(15,7))
for y in y1:
  ax1.plot(k, y, "-o")
for y in y2:
  ax2.plot(k, y, "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Number of Important Words (K)")
plt.title("Polarity Classification Accuracy given Adversarial Examples\n\n")

plt.ylabel("Attacked Accuracy\n")
ax1.set_title("IMDB")
ax2.set_title("Yelp")
# Out:
# Text(0.5, 1.0, 'Yelp')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for y in y3:
  ax1.plot(k3, y, "-o")
query = [
  [122.3278,186.008,236.8229,280.3905],
  [123.2304,180.2623,235.6324,279.3311],
  [135.557,207.0667,265.1007,327.0704],
  [147.8101, 220.4788, 294.9277, 343.7955]
]
rate = [
  [0.175, 0.1681, 0.1618, 0.1502],
  [0.1488, 0.1406, 0.1344, 0.1279],
  [0.1749, 0.1656, 0.1604, 0.1565],
  [0.1724, 0.1656, 0.1579, 0.1523]
]
for i in range(len(model)):
  ax2.plot(query[i], rate[i], "-o")

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.title("News Category Classification on AG News\n")

ax1.set_xlabel("Number of Important Words (K)")
ax1.set_ylabel("Attacked Accuracy")
ax2.legend(model)
ax2.set_ylabel("Change Rate")
ax2.set_xlabel("Average Number of Queries")
# Out:
# Text(0.5, 0, 'Average Number of Queries')

# %%
q1 = [
  [424.163,484.9524,545.4209],
  [416.3281,527.178,598.8368],
  [448.4331,539.7084,600.712],
  [412.7146, 524.1146, 615.5665]
]
c1 = [
  [0.0532, 0.0419, 0.0377],
  [0.04, 0.035, 0.0321],
  [0.0481, 0.038, 0.0339],
  [0.0377, 0.0352, 0.0323]
]
q2 = [
  [283.471, 344.8586, 392.2561],
  [315.7732, 391.4345, 464.0845], 
  [295.125, 360.2913, 427.0629],
  [303.1729, 371.8616, 418.902]
]
c2 = [
  [0.0672, 0.0571, 0.0506], [0.0608, 0.0531, 0.0489], [0.0653, 0.0534, 0.0481], [0.0588, 0.0485, 0.0425]
]
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(15,7))
for i in range(len(model)):
  ax1.plot(q1[i], c1[i], "-o")
for i in range(len(model)):
  ax2.plot(q2[i], c2[i], "-o")
plt.legend(model)

f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Average Number of Queries")
plt.title("Polarity Classification with Queries vs Change Rate\n\n")

plt.ylabel("Change Rate\n")
ax1.set_title("IMDB")
ax2.set_title("Yelp")
# Out:
# Text(0.5, 1.0, 'Yelp')
